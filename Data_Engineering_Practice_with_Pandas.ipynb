# %%
import pandas as pd

# %%
data = [[1, 2, 3], [4, 5, 6], [0, 0, 0]]

# %%
dataframe = pd.DataFrame(data, columns=["Äge", "Height", "Zone"], index=["One", "Two", "Three"])

# %%
print(dataframe)
# Out:
#        Äge  Height  Zone
# One      1       2     3
# Two      4       5     6
# Three    0       0     0

# %%
ads_data = pd.read_csv("Social_Network_Ads.csv")

# %%
ads_data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
purchased_yes = ads_data["Purchased"] == 1

# %%
ads_data[purchased_yes]
# Out:
#      Age  EstimatedSalary  Purchased
# 7     32           150000          1
# 16    47            25000          1
# 17    45            26000          1
# 18    46            28000          1
# 19    48            29000          1
# ..   ...              ...        ...
# 393   60            42000          1
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 399   49            36000          1
#
# [143 rows x 3 columns]

# %%
purchased_no = ads_data["Purchased"] == 0

# %%
ads_data[purchased_no]
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 377   42            53000          0
# 380   42            64000          0
# 387   39            71000          0
# 394   39            59000          0
# 398   36            33000          0
#
# [257 rows x 3 columns]

# %%
len(ads_data[purchased_yes])
# Out:
# 143

# %%
len(ads_data[purchased_no])
# Out:
# 257

# %%
young_people = (ads_data.loc[:, "Age"] > 18) & (ads_data.loc[:, "Age"] <= 30)

# %%
ads_data[young_people]
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# 5     27            58000          0
# ..   ...              ...        ...
# 193   19            70000          0
# 194   28            89000          0
# 196   30            79000          0
# 197   20            36000          0
# 198   26            80000          0
#
# [106 rows x 3 columns]

# %%
ads_data.head(2)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0

# %%
ads_data["EstimatedSalary"].mean()
# Out:
# 69742.5

# %%
average_earner = ads_data.loc[:, "EstimatedSalary"] >= 69742.5

# %%
ads_data[average_earner]
# Out:
#      Age  EstimatedSalary  Purchased
# 4     19            76000          0
# 6     27            84000          0
# 7     32           150000          1
# 10    26            80000          0
# 12    20            86000          0
# ..   ...              ...        ...
# 374   37            80000          0
# 376   46            74000          0
# 378   41            87000          1
# 382   44           139000          1
# 387   39            71000          0
#
# [201 rows x 3 columns]

# %%
bought = ads_data.loc[:, "Age"] * ads_data.loc[:, "Purchased"]

# %%
ads_data[bought]
# Out:
#      Age  EstimatedSalary  Purchased  Did Purchase
# 7     32           150000          1            32
# 16    47            25000          1            47
# 17    45            26000          1            45
# 18    46            28000          1            46
# 19    48            29000          1            48
# ..   ...              ...        ...           ...
# 393   60            42000          1            60
# 395   46            41000          1            46
# 396   51            23000          1            51
# 397   50            20000          1            50
# 399   49            36000          1            49
#
# [143 rows x 4 columns]
