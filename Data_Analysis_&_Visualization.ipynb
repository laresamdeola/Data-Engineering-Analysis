# %% [markdown]
# <a href="https://colab.research.google.com/github/laresamdeola/Data-Engineering-Analysis/blob/main/Data_Analysis_%26_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('kc_house_data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.mean(numeric_only=True)
# Out:
# id               4.580302e+09
# price            5.400881e+05
# bedrooms         3.370842e+00
# bathrooms        2.114757e+00
# sqft_living      2.079900e+03
# sqft_lot         1.510697e+04
# floors           1.494309e+00
# waterfront       7.541757e-03
# view             2.343034e-01
# condition        3.409430e+00
# grade            7.656873e+00
# sqft_above       1.788391e+03
# sqft_basement    2.915090e+02
# yr_built         1.971005e+03
# yr_renovated     8.440226e+01
# zipcode          9.807794e+04
# lat              4.756005e+01
# long            -1.222139e+02
# sqft_living15    1.986552e+03
# sqft_lot15       1.276846e+04
# dtype: float64

# %%
data.max()
# Out:
# id                    9900000190
# date             20150527T000000
# price                  7700000.0
# bedrooms                      33
# bathrooms                    8.0
# sqft_living                13540
# sqft_lot                 1651359
# floors                       3.5
# waterfront                     1
# view                           4
# condition                      5
# grade                         13
# sqft_above                  9410
# sqft_basement               4820
# yr_built                    2015
# yr_renovated                2015
# zipcode                    98199
# lat                      47.7776
# long                    -121.315
# sqft_living15               6210
# sqft_lot15                871200
# dtype: object

# %%
data.sum(numeric_only=True)
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.865249e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %%
data.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
data.mode(numeric_only=True)
# Out:
#             id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  795000620.0  350000.0       3.0        2.5       1300.0    5000.0     1.0
# 1          NaN  450000.0       NaN        NaN          NaN       NaN     NaN
# 2          NaN       NaN       NaN        NaN          NaN       NaN     NaN
# 3          NaN       NaN       NaN        NaN          NaN       NaN     NaN
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0         0.0   0.0        3.0    7.0      1300.0            0.0    2014.0
# 1         NaN   NaN        NaN    NaN         NaN            NaN       NaN
# 2         NaN   NaN        NaN    NaN         NaN            NaN       NaN
# 3         NaN   NaN        NaN    NaN         NaN            NaN       NaN
#
#    yr_renovated  zipcode      lat    long  sqft_living15  sqft_lot15
# 0           0.0  98103.0  47.5322 -122.29         1540.0      5000.0
# ...

# %%
data.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
data.describe(include='object')
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Calculating the Mean/Average

# %%
price_mean = data.loc[:, 'price'].mean()
bedrooms_mean = data.loc[:, 'bedrooms'].mean()
bathrooms_mean = data.loc[:, 'bathrooms'].mean()
condition_mean = data.loc[:, 'condition'].mean()

# %%
print(f'Price Mean: {price_mean}\nBedrooms Mean: {bedrooms_mean}\nBathrooms Mean: {bathrooms_mean}\nCondition Mean: {condition_mean}')
# Out:
# Price Mean: 540088.1417665294
# Bedrooms Mean: 3.37084162309721
# Bathrooms Mean: 2.1147573219821405
# Condition Mean: 3.4094295100171195

# %% [markdown]
# Calculating Sum

# %%
price_sum = data.loc[:, 'price'].sum()
bedrooms_sum = data.loc[:, 'bedrooms'].sum()
bathrooms_sum = data.loc[:, 'bathrooms'].sum()
condition_sum = data.loc[:, 'condition'].sum()

# %%
print(f'Price Sum: {price_sum}\nBedrooms Sum: {bedrooms_sum}\nBathrooms Sum: {bathrooms_sum}\nCondition Sum: {condition_sum}')
# Out:
# Price Sum: 11672925008.0
# Bedrooms Sum: 72854
# Bathrooms Sum: 45706.25
# Condition Sum: 73688

# %% [markdown]
# Calculating Min

# %%
price_min = data.loc[:, 'price'].min()
bedrooms_min = data.loc[:, 'bedrooms'].min()
bathrooms_min = data.loc[:, 'bathrooms'].min()
condition_min = data.loc[:, 'condition'].min()

# %%
print(f'Price Min: {price_min}\nBedrooms Min: {bedrooms_min}\nBathrooms Min: {bathrooms_min}\nCondition Min: {condition_min}')
# Out:
# Price Min: 75000.0
# Bedrooms Min: 0
# Bathrooms Min: 0.0
# Condition Min: 1

# %% [markdown]
# Calculating Max

# %%
price_max = data.loc[:, 'price'].max()
bedrooms_max = data.loc[:, 'bedrooms'].max()
bathrooms_max = data.loc[:, 'bathrooms'].max()
condition_max = data.loc[:, 'condition'].max()

# %%
print(f'Price Max: {price_max}\nBedrooms Max: {bedrooms_max}\nBathrooms Max: {bathrooms_max}\nCondition Max: {condition_max}')
# Out:
# Price Max: 7700000.0
# Bedrooms Max: 33
# Bathrooms Max: 8.0
# Condition Max: 5

# %% [markdown]
# Calculating Median

# %%
price_median = data.loc[:, 'price'].median()
bedrooms_median = data.loc[:, 'bedrooms'].median()
bathrooms_median = data.loc[:, 'bathrooms'].median()
condition_median = data.loc[:, 'condition'].median()

# %%
print(f'Price Median: {price_median}\nBedrooms Median: {bedrooms_median}\nBathrooms Median: {bathrooms_median}\nCondition Median: {condition_median}')
# Out:
# Price Median: 450000.0
# Bedrooms Median: 3.0
# Bathrooms Median: 2.25
# Condition Median: 3.0

# %% [markdown]
# Calculating Mode

# %%
price_mode = data.loc[:, 'price'].mode()
bedrooms_mode = data.loc[:, 'bedrooms'].mode()
bathrooms_mode = data.loc[:, 'bathrooms'].mode()
condition_mode = data.loc[:, 'condition'].mode()

# %%
print(f'Price Mode: {price_mode}\nBedrooms Mode: {bedrooms_mode}\nBathrooms Mode: {bathrooms_mode}\nCondition Mode: {condition_mode}')
# Out:
# Price Mode: 0    350000.0
# 1    450000.0
# Name: price, dtype: float64
# Bedrooms Mode: 0    3
# Name: bedrooms, dtype: int64
# Bathrooms Mode: 0    2.5
# Name: bathrooms, dtype: float64
# Condition Mode: 0    3
# Name: condition, dtype: int64

# %% [markdown]
# Calculating Count

# %%
price_max = data.loc[:, 'price'].max()
bedrooms_max = data.loc[:, 'bedrooms'].max()
bathrooms_max = data.loc[:, 'bathrooms'].max()
condition_max = data.loc[:, 'condition'].max()

# %%
print(f'Price Min: {price_min}\nBedrooms Min: {bedrooms_min}\nBathrooms Min: {bathrooms_min}\nCondition Min: {condition_min}')

# %% [markdown]
# Calculating Describe

# %%
price_max = data.loc[:, 'price'].max()
bedrooms_max = data.loc[:, 'bedrooms'].max()
bathrooms_max = data.loc[:, 'bathrooms'].max()
condition_max = data.loc[:, 'condition'].max()

# %%
print(f'Price Min: {price_min}\nBedrooms Min: {bedrooms_min}\nBathrooms Min: {bathrooms_min}\nCondition Min: {condition_min}')
