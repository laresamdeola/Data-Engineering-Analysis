# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data4.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               120 non-null    object
#  1   region             120 non-null    object
#  2   beverages_units    120 non-null    int64
#  3   food_units         120 non-null    int64
#  4   electronics_units  120 non-null    int64
#  5   clothes_units      120 non-null    int64
#  6   tools_units        120 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 6.7+ KB

# %%
data.describe()
# Out:
#        beverages_units  food_units  electronics_units  clothes_units  \
# count       120.000000  120.000000         120.000000     120.000000
# mean         84.225000   71.766667          84.575000      80.858333
# std          64.556205   56.199335          62.029224      62.400751
# min           3.000000    0.000000           0.000000       1.000000
# 25%          34.750000   31.500000          34.750000      30.500000
# 50%          62.000000   51.500000          73.500000      70.000000
# 75%         126.000000  104.750000         126.500000     114.000000
# max         281.000000  259.000000         272.000000     230.000000
#
#        tools_units
# count   120.000000
# mean     72.075000
# std      52.595837
# min       0.000000
# 25%      25.750000
# 50%      67.500000
# 75%     106.750000
# max     187.000000

# %%
data.head()
# Out:
#          date region  beverages_units  food_units  electronics_units  \
# 0  2020-06-01  SIN51               28         209                114
# 1           -  DUB53               33         149                 31
# 2           -  IAD77              228          77                140
# 3           -  PDX79              269          24                 16
# 4  2020-06-02  SIN51              281          89                 74
#
#    clothes_units  tools_units
# 0             19           50
# 1             90            9
# 2            198           45
# 3            225           67
# 4             19            3

# %%
data.loc[:, "total_products"] = data.loc[:, "beverages_units"] + data.loc[:, "food_units"] + data.loc[:, "electronics_units"] + data.loc[:, "clothes_units"] + data.loc[:, "tools_units"]

# %%
data.head()
# Out:
#          date region  beverages_units  food_units  electronics_units  \
# 0  2020-06-01  SIN51               28         209                114
# 1           -  DUB53               33         149                 31
# 2           -  IAD77              228          77                140
# 3           -  PDX79              269          24                 16
# 4  2020-06-02  SIN51              281          89                 74
#
#    clothes_units  tools_units  total_products
# 0             19           50             420
# 1             90            9             312
# 2            198           45             688
# 3            225           67             601
# 4             19            3             466

# %%
oregon = data.loc[:, "region"] == "SIN51"

# %%
oregon_data = data[oregon]

# %%
oregon_data.head()
# Out:
#           date region  beverages_units  food_units  electronics_units  \
# 0   2020-06-01  SIN51               28         209                114
# 4   2020-06-02  SIN51              281          89                 74
# 8   2020-06-03  SIN51              131          32                128
# 12  2020-06-04  SIN51               58           4                 58
# 16  2020-06-05  SIN51               54          65                 50
#
#     clothes_units  tools_units  total_products
# 0              19           50             420
# 4              19            3             466
# 8             180           81             552
# 12             49           22             191
# 16             47          120             336

# %%
oregon_data.tail()
# Out:
#            date region  beverages_units  food_units  electronics_units  \
# 100  2020-06-26  SIN51               24         108                 77
# 104  2020-06-27  SIN51               58         155                 53
# 108  2020-06-28  SIN51               54          38                 43
# 112  2020-06-29  SIN51               46          36                 21
# 116  2020-06-30  SIN51               21           1                 60
#
#      clothes_units  tools_units  total_products
# 100             66          105             380
# 104             80           67             413
# 108             36           58             229
# 112            139          128             370
# 116            220           59             361

# %%
oregon_data.loc[:, "total_products"].max()
# Out:
# 666

# %%
max_date = oregon_data.loc[:, "total_products"] == 666

# %%
oregon_data[max_date]
# Out:
#           date region  beverages_units  food_units  electronics_units  \
# 96  2020-06-25  SIN51               30         242                171
#
#     clothes_units  tools_units  total_products
# 96            107          116             666

# %%
data.loc[:, "clothes_units"].min()
# Out:
# 1

# %%
min_clothes_units = data.loc[:, "clothes_units"] == 1

# %%
data[min_clothes_units]
# Out:
#           date region  beverages_units  food_units  electronics_units  \
# 18           -  IAD77               27          22                141
# 22           -  IAD77               57           1                  3
# 35           -  PDX79               41          43                110
# 36  2020-06-10  SIN51               12         135                117
#
#     clothes_units  tools_units  total_products
# 18              1           33             224
# 22              1           87             149
# 35              1           15             210
# 36              1           98             363

# %%
dublin = data.loc[:, "region"] == "DUB53"

# %%
dublin
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 115    False
# 116    False
# 117     True
# 118    False
# 119    False
# Name: region, Length: 120, dtype: bool

# %%
dublin_data = data[dublin]

# %%
dublin_data.head()
# Out:
#    date region  beverages_units  food_units  electronics_units  clothes_units  \
# 1     -  DUB53               33         149                 31             90
# 5     -  DUB53               79           8                 45             98
# 9     -  DUB53               29          40                117            139
# 13    -  DUB53               10          63                 41            210
# 17    -  DUB53              113         161                165             88
#
#     tools_units  total_products
# 1             9             312
# 5            56             286
# 9            81             406
# 13          109             433
# 17            9             536

# %%
more_clothes = dublin_data.loc[:, "clothes_units"] > dublin_data.loc[:, "electronics_units"]

# %%
dublin_data[more_clothes].count()
# Out:
# date                 12
# region               12
# beverages_units      12
# food_units           12
# electronics_units    12
# clothes_units        12
# tools_units          12
# total_products       12
# dtype: int64

# %%
region_with_more_food = data.loc[:, "food_units"] > data.loc[:, "electronics_units"]

# %%
data[region_with_more_food]
# Out:
#            date region  beverages_units  food_units  electronics_units  \
# 0    2020-06-01  SIN51               28         209                114
# 1             -  DUB53               33         149                 31
# 3             -  PDX79              269          24                 16
# 4    2020-06-02  SIN51              281          89                 74
# 6             -  IAD77               84         178                122
# 13            -  DUB53               10          63                 41
# 16   2020-06-05  SIN51               54          65                 50
# 20   2020-06-06  SIN51               76         157                  2
# 25            -  DUB53               36         149                 40
# 26            -  IAD77              156          83                 79
# 29            -  DUB53              130          40                 34
# 31            -  PDX79               21          86                 33
# ...

# %%
beverages_data = data.loc[:, "beverages_units"]

# %%
beverages_data.max()
# Out:
# 281

# %%
beverages_data.describe()
# Out:
# count    120.000000
# mean      84.225000
# std       64.556205
# min        3.000000
# 25%       34.750000
# 50%       62.000000
# 75%      126.000000
# max      281.000000
# Name: beverages_units, dtype: float64

# %%
beverage_75 = data.loc[:, "beverages_units"] > 84

# %%
data[beverage_75]
# Out:
#            date region  beverages_units  food_units  electronics_units  \
# 2             -  IAD77              228          77                140
# 3             -  PDX79              269          24                 16
# 4    2020-06-02  SIN51              281          89                 74
# 8    2020-06-03  SIN51              131          32                128
# 10            -  IAD77              261           2                 19
# 15            -  PDX79              152          33                154
# 17            -  DUB53              113         161                165
# 19            -  PDX79              152          43                 94
# 23            -  PDX79              116          84                172
# 26            -  IAD77              156          83                 79
# 28   2020-06-08  SIN51              173          51                 71
# 29            -  DUB53              130          40                 34
# ...

# %%
beverages_frame = pd.DataFrame(beverages_data)

# %%
beverages_frame
# Out:
#      beverages_units
# 0                 28
# 1                 33
# 2                228
# 3                269
# 4                281
# ..               ...
# 115               50
# 116               21
# 117              129
# 118               63
# 119               45
#
# [120 rows x 1 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
beverage_70 = data.loc[:, "beverages_units"].quantile(q=0.7)

# %%
beverage_70
# Out:
# 115.3

# %%
beverage_70_upper_bound = data.loc[:, "beverages_units"].quantile(q=0.71)

# %%
beverage_70_upper_bound
# Out:
# 116.0

# %%
the_quantile = (data.loc[:, "beverages_units"] >= 115) & (data.loc[:, "beverages_units"] < 116)

# %%
data[the_quantile]
# Out:
#     date region  beverages_units  food_units  electronics_units  \
# 111    -  PDX79              115          40                 26
#
#      clothes_units  tools_units  total_products
# 111             10           93             284

# %%
type(beverages_data)
# Out:
# pandas.core.series.Series

# %%
beverage_70_quantile = data.loc[:, "beverages_units"] == beverages_70

# %%
beverage_70_quantile
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# Name: beverages_units, Length: 120, dtype: bool
